# %%
import pandas as pd

# importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

# selecionando as colunas desejadas
clientes_df = clientes_df[['ID Cliente','E-mail']]
produtos_df = produtos_df[['ID Produto','Nome do Produto']]
lojas_df = lojas_df[['ID Loja','Nome da Loja']]

# mesclando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')

# renomeando coluna
vendas_df = vendas_df.rename(columns={'E-mail': 'E-mail do Cliente'})

display(vendas_df.head())
display(vendas_df.info())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1           880458    23/11/2017    23/11/2017         0      306         235
# 2           191019    20/03/2017    21/03/2017         1      172         376
# 3            18610    08/01/2017    10/01/2017         2      200         448
# 4           287704    23/04/2017    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %%
# Convertendo coluna Data da Venda para datetime
vendas_df['Data da Venda'] = pd.to_datetime(vendas_df['Data da Venda'], format='%d/%m/%Y')

display(vendas_df.head())
display(vendas_df.info())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    2017-01-01    02/01/2017         1       86         981
# 1           880458    2017-11-23    23/11/2017         0      306         235
# 2           191019    2017-03-20    21/03/2017         1      172         376
# 3            18610    2017-01-08    10/01/2017         2      200         448
# 4           287704    2017-04-23    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %%
# Adicionado coluna de dia, mês e ano
vendas_df['Dia da Venda'] = vendas_df['Data da Venda'].dt.day
vendas_df['Mês da Venda'] = vendas_df['Data da Venda'].dt.month
vendas_df['Ano da Venda'] = vendas_df['Data da Venda'].dt.year

display(vendas_df.head())
display(vendas_df.info())
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    2017-01-01    02/01/2017         1       86         981
# 1           880458    2017-11-23    23/11/2017         0      306         235
# 2           191019    2017-03-20    21/03/2017         1      172         376
# 3            18610    2017-01-08    10/01/2017         2      200         448
# 4           287704    2017-04-23    26/04/2017         3       76         280
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1           10        6825                   8                     0
# 2            2        6825                   9                     0
# 3            2        6825                  48                     0
# 4            1        6825                  10                     0
#
#                                      Nome do Produto  \
# ...

# %%
# Usando loc e unloc
novo_produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
novo_produtos_df = novo_produtos_df.set_index('Nome do Produto')

display(novo_produtos_df.head())

print(novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario'])
print(novo_produtos_df.iloc[0, 5])
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...

# %%
# Aumentando o preço do ID Produto 873 para 23

novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario'] = '23'

display(novo_produtos_df.head())
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...

# %%
# Outra forma de modificar um valor

novo_produtos_df.loc[novo_produtos_df['ID Produto'] == 873, 'Preco Unitario'] = '25'

display(novo_produtos_df.head())
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...
